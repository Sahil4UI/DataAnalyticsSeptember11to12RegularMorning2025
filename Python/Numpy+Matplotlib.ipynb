# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1,10)
x
# Out:
# array([ 1.        ,  1.18367347,  1.36734694,  1.55102041,  1.73469388,
#         1.91836735,  2.10204082,  2.28571429,  2.46938776,  2.65306122,
#         2.83673469,  3.02040816,  3.20408163,  3.3877551 ,  3.57142857,
#         3.75510204,  3.93877551,  4.12244898,  4.30612245,  4.48979592,
#         4.67346939,  4.85714286,  5.04081633,  5.2244898 ,  5.40816327,
#         5.59183673,  5.7755102 ,  5.95918367,  6.14285714,  6.32653061,
#         6.51020408,  6.69387755,  6.87755102,  7.06122449,  7.24489796,
#         7.42857143,  7.6122449 ,  7.79591837,  7.97959184,  8.16326531,
#         8.34693878,  8.53061224,  8.71428571,  8.89795918,  9.08163265,
#         9.26530612,  9.44897959,  9.63265306,  9.81632653, 10.        ])

# %%
y = x ** 2

# %%
plt.title("X vs Y")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x,y,color="y")#line Graph

# %%
x1 = np.random.randn(100,2) * [-2,2]
x1
# Out:
# array([[ 1.80697277e+00,  3.04230150e+00],
#        [ 1.55633042e+00,  3.42050887e+00],
#        [-1.86188967e-01,  7.33724104e-01],
#        [ 8.70946582e-01, -3.92141687e-01],
#        [-8.12329349e-01,  1.56134041e+00],
#        [ 1.20544885e+00, -1.78442312e+00],
#        [-6.80115671e-01,  6.97241151e-01],
#        [ 1.17885691e+00,  4.21396916e-01],
#        [-2.67631013e-01,  3.13644522e+00],
#        [ 2.16102339e-01,  5.70974524e+00],
#        [ 2.41797342e-01,  1.79319091e+00],
#        [-3.88528230e-01,  2.97360033e+00],
#        [-1.92788422e-03, -2.34350479e+00],
#        [-1.09296592e+00, -3.05721287e+00],
#        [ 1.31811064e-01,  2.46781516e+00],
#        [ 1.71990891e+00,  1.87866710e+00],
#        [-4.40180884e+00, -1.05369535e+00],
#        [ 2.99654116e-01, -3.19710078e+00],
#        [ 3.95309805e+00, -4.64858464e-01],
#        [-4.82902179e-01, -2.42865519e-01],
#        [-1.96693110e+00, -1.34659816e+00],
#        [-3.26968957e+00,  1.31252897e+00],
# ...

# %%
x2 = np.random.randn(100,2) * [2,-2]

# %%
print(x1.shape)
# Out:
# (100, 2)

# %%
c = np.vstack((x1,x2))

# %%
plt.scatter(x1,x2,color="r")#rgb - red,green,blue , cmyk - cyan magenta yellow black

# %%
y = np.zeros(200)

# %%
y[100:] = 1.0

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %%
plt.hist(x[:  ,0])
# Out:
# (array([ 2.,  5.,  6., 25., 39., 49., 42., 19., 11.,  2.]),
#  array([-6.28516038, -5.08530543, -3.88545048, -2.68559554, -1.48574059,
#         -0.28588564,  0.91396931,  2.11382425,  3.3136792 ,  4.51353415,
#          5.71338909]),
#  <BarContainer object of 10 artists>)

# %%
x1 = np.random.randn(300,2) * [-2,2]
x2 = np.random.randn(300,2) * [2,-2]
x = np.vstack((x1,x2))

# %%
plt.hist(x[:,1])
plt.show()
